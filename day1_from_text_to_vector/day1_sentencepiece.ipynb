# %% [markdown]
# Google 에서도 sentencepiece 라는 이름으로 Word Piece Model package 를 공개하였습니다. 설치는 pip install 로 가능합니다. 실습 환경에서의 버전은 `sentencepiece==0.1.8` 입니다.
#
# ```
# pip install sentencepiece
# ```
#
# 학습 데이터는 빈 칸이 포함되지 않은 문서 집합입니다. 우리의 실습 데이터에는 정규화 과정에서 한문으로만 이뤄진 기사의 텍스트가 지워졌기 때문에 빈 줄이 포함되어 있습니다. 이 빈 줄을 제거하여 `spm_input.txt` 파일을 만듭니다.

# %%
import config
import sentencepiece as spm
from navernews_10days import get_news_paths
from soynlp.utils import DoublespaceLineCorpus

path = get_news_paths(date='2016-10-20', tokenize=None)
corpus = DoublespaceLineCorpus(path, iter_sent=True, num_doc=1000)

input_file = 'spm_input.txt'
with open(input_file, 'w', encoding='utf-8') as f:
    for sent in corpus:
        f.write('{}\n'.format(sent))

# %% [markdown]
# Sentencepiece 는 C++ 로 구현되어 있으며, subprocess 를 이용하여 파이썬에서 스크립트를 실행시키는 방식입니다. Input 은 반드시 텍스트 파일이어야 합니다. command message 는 input, prefix, vocab_size 를 입력해야 합니다.
#
# IPython notebook 에서는 파이썬 스크립트에서 오류가 날 경우 커널이 그대로 죽습니다. 파이썬 인터프리터에서 직접 작업하면 코드의 오류를 볼 수 있습니다. vocab_size 가 지나치게 작게 설정되면 모델이 학습을 하다 오류를 발생시킵니다. 당황하지 마시고 vocab_size 를 키우면 됩니다. 우리의 실습 예시에서는 vocab_size 1000 으로 설정하면 오류가 발생합니다. 2000 으로 키우면 문제없이 작동합니다.

# %%
templates = '--input={} --model_prefix={} --vocab_size={}'

vocab_size = 2000
prefix = '2016-10-20-news'
cmd = templates.format(input_file, prefix, vocab_size)

spm.SentencePieceTrainer.Train(cmd)
# Out:
# True

# %% [markdown]
# 학습이 끝나면 `2016-10-20-news` 라는 prefix 를 지니는 .model 파일과 .vocab 파일이 만들어집니다.

# %%
ls
# Out:
# 2016-10-20-news.model  day1_load_dataset_with_soynlp.ipynb    spm_input.txt
# 2016-10-20-news.vocab  day1_sentencepiece.ipynb               userdic.txt
# config.py              day1_soynlp_word_noun_tokenizer.ipynb
# day1_KoNLPy.ipynb      __pycache__/

# %% [markdown]
# 학습된 모델을 이용하려면 .model 을 로딩합니다.

# %%
sp = spm.SentencePieceProcessor()
sp.Load('{}.model'.format(prefix))
# Out:
# True

# %% [markdown]
# 문장을 입력하면 subword list 로 출력할 수 있습니다.

# %%
sp.EncodeAsPieces('오늘의 연합뉴스 기사입니다')
# Out:
# ['▁오', '늘', '의', '▁연합뉴스', '▁기', '사', '입', '니', '다']

# %% [markdown]
# 혹은 subword idx list 로 출력할 수도 있습니다.

# %%
sp.EncodeAsIds('오늘의 연합뉴스 기사입니다')
# Out:
# [203, 870, 7, 23, 171, 26, 327, 186, 25]

# %% [markdown]
# 우리가 설정한 2000 개의 vocabulary 가 학습되었습니다.

# %%
with open('{}.vocab'.format(prefix), encoding='utf-8') as f:
    vocabs = [doc.strip() for doc in f]

print('num of vocabs = {}'.format(len(vocabs)))
# Out:
# num of vocabs = 2000

# %% [markdown]
# Vocabulary 에는 unknown, 문장의 시작, 문장의 끝, 단어의 앞부분 등 네 가지의 special token 이 있으며, 그 외에는 `을`, `이`, `의`, `는` 과 같은 조사들이 뒤따릅니다. `_기자`, `_재배포` 와 같은 도메인에서 자주 이용되는 단어들도 포함되어 있습니다.

# %%
for vocab in vocabs:
    print(vocab)
# Out:
# <unk>	0
# <s>	0
# </s>	0
# ▁	-2.3141
# 을	-3.95619
# 이	-4.13792
# 는	-4.17755
# 의	-4.2608
# 에	-4.27495
# 를	-4.47744
# 은	-4.56576
# 가	-4.56862
# 한	-4.77574
# 고	-4.7846
# 도	-4.86284
# 에서	-4.93985
# 일	-4.98635
# 로	-5.02946
# 기	-5.11131
# 과	-5.1414
# 지	-5.15338
# 인	-5.24579
# 해	-5.31501
# ▁연합뉴스	-5.3214
# ▁20	-5.33494
# 다	-5.397
# 사	-5.41258
# ▁있다	-5.42713
# 리	-5.45189
# 으로	-5.45349
# ▁이	-5.47303
# 자	-5.52116
# 장	-5.52249
# 시	-5.58215
# ▁등	-5.59042
# ▁수	-5.61918
# 원	-5.62017
# 했다	-5.6344
# 대	-5.63529
# 정	-5.66812
# 하는	-5.74145
# 하고	-5.76434
# 와	-5.78018
# 년	-5.79992
# ▁서울	-5.82273
# ▁전	-5.8357
# 할	-5.84419
# 수	-5.85506
# 주	-5.85524
# ▁고	-5.89186
# ▁2	-5.92829
# 나	-5.95039
# ▁기자	-5.95057
# 상	-5.96083
# 전	-5.96911
# 스	-5.9739
# ▁3	-5.97818
# ▁1	-6.00681
# 만	-6.01671
# 어	-6.02466
# 성	-6.07467
# 부	-6.08663
# ▁10	-6.10234
# 제	-6.1093
# 서	-6.1269
# 천	-6.13931
# 구	-6.14533
# 화	-6.19967
# 면	-6.20454
# 들	-6.21878
# 하	-6.21914
# ▁김	-6.22977
# 회	-6.24134
# 명	-6.24962
# 게	-6.25369
# 선	-6.25562
# 진	-6.28571
# 월	-6.29294
# ▁2016	-6.29878
# 며	-6.30346
# 적	-6.3347
# 산	-6.35707
# ▁것	-6.36179
# 치	-6.37269
# ▁부	-6.37915
# 동	-6.38136
# 계	-6.39012
# 소	-6.39247
# 조	-6.39716
# 드	-6.40723
# ▁중	-6.40864
# 금	-6.42985
# ▁그	-6.43179
# 라	-6.43809
# 국	-6.4468
# ▁5	-6.45081
# 세	-6.46745
# ▁정	-6.47052
# 아	-6.47071
# ▁유	-6.47934
# ▁사	-6.4848
# ▁4	-6.49744
# 한다	-6.50626
# ▁19	-6.5067
# ▁보	-6.51178
# ▁지	-6.53141
# 재	-6.53246
# 용	-6.5511
# 2	-6.55212
# 개	-6.55386
# 당	-6.56287
# 트	-6.5698
# ▁제	-6.58065
# 간	-6.58478
# 여	-6.58544
# ▁주	-6.58614
# ▁것으로	-6.58746
# 체	-6.59651
# 1	-6.59848
# 된	-6.60114
# ▁공	-6.60227
# 무	-6.60231
# 공	-6.60357
# ▁가	-6.61133
# 관	-6.6366
# ▁시	-6.63747
# ▁오전	-6.6421
# 위	-6.64388
# ▁대	-6.64444
# 차	-6.64568
# 력	-6.65885
# 비	-6.66041
# ▁한	-6.66183
# 단	-6.66217
# 식	-6.66379
# ▁있는	-6.66878
# ▁북한	-6.67354
# 3	-6.68111
# ▁아	-6.68633
# 호	-6.69217
# 보	-6.70445
# ▁연	-6.7137
# 행	-6.71662
# 연	-6.7277
# ▁제공	-6.73013
# 경	-6.73056
# ▁6	-6.7327
# 유	-6.73785
# 5	-6.74523
# ▁위	-6.75159
# 안	-6.75767
# ▁미국	-6.76044
# 영	-6.77354
# 야	-6.7757
# ▁말했다	-6.77587
# 중	-6.77614
# 히	-6.78506
# 마	-6.79134
# ▁신	-6.79413
# 운	-6.79472
# 문	-6.79616
# 업	-6.79791
# 7	-6.79937
# ▁인	-6.80012
# 까지	-6.8026
# ▁7	-6.80877
# 법	-6.81409
# 학	-6.82336
# 던	-6.82631
# ▁내	-6.83477
# 9	-6.84767
# ▁기	-6.84838
# 6	-6.85245
# 모	-6.85353
# 물	-6.85804
# ▁밝혔다	-6.86307
# 8	-6.86339
# 됐다	-6.86368
# 이다	-6.86411
# 권	-6.8732
# 군	-6.87947
# ▁8	-6.88044
# 방	-6.88218
# 신	-6.88333
# ▁한국	-6.90543
# 들이	-6.9156
# 니	-6.9275
# ▁비	-6.93501
# 형	-6.93609
# 4	-6.93908
# 려	-6.94312
# 약	-6.94735
# ▁나	-6.95064
# 건	-6.95914
# ▁9	-6.96453
# 처	-6.96469
# ▁박	-6.96969
# ▁열린	-6.97111
# ▁특	-6.98592
# ▁있	-6.98608
# ▁소	-6.98981
# 크	-6.99224
# 내	-6.99455
# ▁오	-6.99803
# 지만	-6.99987
# ▁대한	-7.0043
# 출	-7.01714
# ▁강	-7.02452
# 발	-7.02498
# 청	-7.02832
# 격	-7.033
# 된다	-7.03399
# ▁불	-7.03709
# 직	-7.03733
# ▁동	-7.03828
# 급	-7.04342
# 분	-7.04465
# 생	-7.05107
# 실	-7.06192
# 우	-7.06507
# 시간	-7.06922
# ▁미	-7.06959
# ▁자	-7.07026
# 품	-7.07924
# 파	-7.08621
# 태	-7.09235
# ▁위해	-7.09364
# 질	-7.09364
# 석	-7.09996
# 합	-7.11804
# 0	-7.12236
# 르	-7.13373
# 터	-7.13902
# ▁배	-7.14142
# 하기	-7.14956
# ▁조	-7.15143
# 종	-7.15148
# 보다	-7.1584
# 통	-7.16225
# 적으로	-7.16534
# ▁씨	-7.1692
# 복	-7.1753
# 했	-7.17895
# ▁며	-7.18792
# ▁지난	-7.18903
# ▁한미	-7.19029
# ▁마	-7.19619
# 민	-7.19836
# 심	-7.20067
# 거	-7.20445
# ▁안	-7.21033
# ▁이날	-7.21793
# 양	-7.22182
# 음	-7.22218
# 목	-7.22575
# ▁선	-7.22812
# ▁일	-7.23088
# ▁모	-7.23584
# 점	-7.23637
# ▁경찰	-7.24131
# 환	-7.24837
# 협	-7.25056
# ▁실	-7.25118
# 량	-7.25457
# ▁다	-7.25498
# 적인	-7.25574
# 토	-7.25988
# ▁경	-7.26232
# ▁해	-7.26574
# ▁무	-7.2666
# 른	-7.26833
# ▁호주	-9.01684
# ▁의지	-9.0192
# 메	-9.02209
# ▁보여	-9.02715
# 법인	-9.0297
# ▁기소	-9.03197
# 죄	-9.03555
# 뤄	-9.03557
# ▁덧붙였다	-9.0356
# ▁성과연봉제	-9.0356
# 슨	-9.0356
# 쿠	-9.0356
# ▁대선후보	-9.03561
# ▁질문에	-9.03561
# ▁논란	-9.03565
# ▁설립	-9.03583
# ▁집중	-9.0362
# ▁교통	-9.03856
# ▁국감	-9.03948
# ▁선보	-9.04505
# 여명	-9.04638
# ▁54	-9.04947
# 종합	-9.0501
# 살	-9.0522
# ▁29	-9.05667
# 념	-9.06167
# ▁선정	-9.06245
# 께	-9.06248
# 텍	-9.06338
# 흐	-9.06338
# ▁국무장관	-9.06338
# ▁배출가스	-9.06338
# 갑	-9.06338
# 릴	-9.06338
# 쇼	-9.06338
# 싼	-9.06338
# 킹	-9.06338
# ▁압박	-9.06342
# ▁삼성	-9.06382
# ▁소속	-9.06804
# ▁한강	-9.07074
# ▁대출	-9.0763
# 허	-9.07775
# ▁간사	-9.08021
# 새	-9.08166
# 애	-9.08292
# ▁대학	-9.08546
# 환경	-9.09076
# 굴	-9.09147
# ▁페이스북	-9.09195
# ▁핵심	-9.09195
# 뢰	-9.09195
# ▁토담집	-9.09195
# 즐	-9.09195
# ▁불출석	-9.09196
# ▁오패산	-9.09196
# ▁한라산	-9.09201
# ▁판단	-9.09249
# 냈다	-9.09385
# ▁때문이다	-9.09507
# ▁오른	-9.09778
# ▁사례	-9.09813
# ▁전달	-9.10113
# 천억원	-9.10294
# ▁비용	-9.10578
# 단계	-9.11484
# ▁않았	-9.11767
# 얼	-9.12135
# 컨	-9.12136
# ▁브리핑	-9.12137
# ▁확장억제전략협의체	-9.12137
# ▁힐러리	-9.12137
# 값	-9.12137
# 딩	-9.12137
# 밤	-9.12137
# ▁롯데	-9.12137
# ▁손학규	-9.12137
# 464	-9.12137
# ▁모바일	-9.12139
# ▁우리나라	-9.12143
# 변	-9.14387
# 푸	-9.15167
# 흔	-9.15167
# 칠	-9.18292
# 납	-9.18292
# 먹	-9.18292
# 셜	-9.18292
# 졌	-9.21073
# 풀	-9.21517
# 넓	-9.21518
# 럴	-9.21518
# 빈	-9.21518
# 숙	-9.21518
# 써	-9.21518
# 올	-9.21869
# 케	-9.22038
# 누	-9.22809
# 련	-9.24692
# 춘	-9.2483
# 렌	-9.24851
# 싸	-9.24851
# 첨	-9.24851
# 흘	-9.24851
# 랜	-9.28131
# 놀	-9.28299
# 룡	-9.28299
# 킨	-9.28299
# 흑	-9.28299
# 앙	-9.3169
# 둘	-9.31864
# 십	-9.31871
# 쓴	-9.31871
# 왔	-9.35127
# 렸	-9.35129
# 곤	-9.35574
# 낙	-9.35574
# 링	-9.35574
# 섬	-9.35574
# 짜	-9.35574
# 김	-9.37843
# 꼬	-9.39421
# 듯	-9.39421
# 씩	-9.39421
# 엘	-9.39421
# 잔	-9.39421
# 깨	-9.39421
# 팅	-9.39421
# 농	-9.41718
# 줄	-9.41904
# 것	-9.42011
# 째	-9.42703
# 릉	-9.43421
# 봤	-9.43421
# 캐	-9.47587
# 털	-9.47587
# 헤	-9.47587
# 많	-9.50986
# 특	-9.51159
# 폰	-9.51919
# 붙	-9.51934
# 괄	-9.51935
# 셀	-9.51935
# 떻	-9.51935
# 뛰	-9.51935
# 롭	-9.51935
# 졸	-9.51935
# 줬	-9.51935
# 찍	-9.51935
# 탑	-9.51935
# 럽	-9.5631
# 맹	-9.56373
# 촉	-9.5646
# 큐	-9.5648
# 괴	-9.56481
# 낼	-9.56481
# 콜	-9.56481
# 욱	-9.61194
# 궁	-9.61242
# 꽃	-9.61242
# 렬	-9.61242
# 몇	-9.61242
# 쌀	-9.61242
# 칸	-9.61242
# 휘	-9.61242
# 칼	-9.66242
# 싶	-9.66242
# 왜	-9.66242
# 잉	-9.66242
# 칙	-9.66242
# 콩	-9.66242
# 혹	-9.71369
# 귤	-9.71506
# 릭	-9.71506
# 몸	-9.71506
# 빛	-9.71506
# 솔	-9.71506
# 숲	-9.71506
# 웠	-9.71506
# 짐	-9.71506
# 칭	-9.71506
# 옷	-9.71506
# 때	-9.72992
# 엇	-9.77061
# 낭	-9.77061
# 짓	-9.77061
# 츠	-9.77061
# 뇨	-9.82943
# 닥	-9.82943
# 틸	-9.82943
# 걷	-9.82943
# 꿈	-9.82943
# 롤	-9.82943
# 몽	-9.82943
# 섭	-9.82943
# 씬	-9.82943
# 탕	-9.82943
# 홀	-9.82943
# 끈	-9.89193
# 냥	-9.89193
# 땅	-9.89193
# 쉬	-9.89193
# 훨	-9.89193
# 났	-9.95411
# 냈	-9.95412
# 펀	-9.95844
# 꼭	-9.9586
# 렉	-9.9586
# 맨	-9.9586
# 묘	-9.9586
# 묵	-9.9586
# 밭	-9.9586
# 벼	-9.9586
# 얀	-9.9586
# 찌	-9.9586
# 몬	-9.9586
# 앉	-9.9586
# 엽	-9.9586
# 쓰	-10.0056
# 욕	-10.03
# 둥	-10.03
# 벨	-10.03
# 빼	-10.03
# 춤	-10.03
# 쌍	-10.03
# 앤	-10.03
# 웅	-10.03
# 퓨	-10.03
# 픈	-10.03
# 걸	-10.0905
# 폴	-10.0905
# 못	-10.0907
# 겼	-10.1025
# 녕	-10.107
# 샤	-10.107
# 셰	-10.107
# 줘	-10.107
# 핀	-10.107
# 알	-10.1796
# 뇌	-10.1902
# 랍	-10.1903
# 웹	-10.1903
# 펴	-10.1903
# 삭	-10.1903
# 켈	-10.1903
# 텀	-10.1903
# 넣	-10.1903
# 랄	-10.1903
# 탓	-10.1903
# 잎	-10.1903
# 텐	-10.1903
# 껏	-10.2812
# 끄	-10.2812
# 닝	-10.2812
# 닫	-10.2812
# 뜨	-10.2812
# 렀	-10.2812
# 멘	-10.2812
# 붕	-10.2812
# 빅	-10.2812
# 셉	-10.2812
# 셔	-10.2812
# 쏜	-10.2812
# 즌	-10.2812
# 쿨	-10.2812
# 픽	-10.2812
# 엄	-10.2879
# 닌	-10.3798
# 델	-10.3803
# 벤	-10.3812
# 닉	-10.3812
# 샘	-10.3812
# 쓸	-10.3812
# 첩	-10.3812
# 툼	-10.3812
# 릿	-10.3812
# 멸	-10.3812
# 젠	-10.3812
# 큼	-10.4916
# 갓	-10.4923
# 뮤	-10.4923
# 걱	-10.4923
# 랩	-10.4923
# 럿	-10.4923
# 빙	-10.4923
# 슴	-10.4923
# 컬	-10.4923
# 톤	-10.4923
# 옵	-10.4923
# 돈	-10.5175
# 틴	-10.6173
# 렵	-10.6173
# 랐	-10.6173
# 뱅	-10.6173
# 쥐	-10.6173
# 겁	-10.6173
# 덴	-10.6173
# 뒀	-10.6173
# 빗	-10.6173
# 쁘	-10.6173
# 엠	-10.6173
# 칩	-10.6173
# 킬	-10.6173
# 턱	-10.6173
# 횃	-10.6173
# 넬	-10.7602
# 꾼	-10.7602
# 낀	-10.7602
# 댐	-10.7602
# 됨	-10.7602
# 롱	-10.7602
# 므	-10.7602
# 빵	-10.7602
# 쁜	-10.7602
# 쎄	-10.7602
# 엉	-10.7602
# 횡	-10.7602
# 댄	-10.7602
# 삿	-10.9268
# 껴	-10.9268
# 듀	-10.9268
# 햄	-10.9268
# 꺼	-10.9268
# 꼈	-10.9268
# 딘	-10.9268
# 뚝	-10.9268
# 룸	-10.9268
# 밥	-10.9268
# 봄	-10.9268
# 셨	-10.9268
# 숭	-10.9268
# 엿	-10.9268
# 윗	-10.9268
# 쩍	-10.9268
# 쯤	-10.9268
# 챈	-10.9268
# 츰	-10.9268
# 쾌	-10.9268
# 퀘	-10.9268
# 쿵	-10.9268
# 팡	-10.9268
# 떨	-11.1266
# 덩	-11.1268
# 덜	-11.1268
# 뷰	-11.1268
# 븐	-11.1268
# 톡	-11.1268
# 흠	-11.1268
# 꿨	-11.1268
# 넌	-11.1268
# 놨	-11.1268
# 닐	-11.1268
# 댈	-11.1268
# 뎌	-11.1268
# 둑	-11.1268
# 룩	-11.1268
# 릇	-11.1268
# 봇	-11.1268
# 윈	-11.1268
# 찮	-11.1268
# 츄	-11.1268
# 콕	-11.1268
# 틈	-11.1268
# 퐁	-11.1268
# 뿜	-11.1268
# 옹	-11.1268
# 웰	-11.1268
# 템	-11.3768
# 겐	-11.3768
# 꿔	-11.3768
# 갚	-11.3768
# 깡	-11.3768
# 꿀	-11.3768
# 끔	-11.3768
# 낄	-11.3768
# 냄	-11.3768
# 딜	-11.3768
# 떡	-11.3768
# 랭	-11.3768
# 롬	-11.3768
# 멍	-11.3768
# 뽀	-11.3768
# 쉐	-11.3768
# 잖	-11.3768
# 죠	-11.3768
# 칫	-11.3768
# 켄	-11.3768
# 툴	-11.3768
# 흙	-11.3768
# 샴	-11.3768
# 맞	-11.6062
# 넘	-11.6079
# 팩	-11.7102
# 겉	-11.7102
# 겹	-11.7102
# 곱	-11.7102
# 괌	-11.7102
# 궈	-11.7102
# 깬	-11.7102
# 끽	-11.7102
# 넨	-11.7102
# 눌	-11.7102
# 늄	-11.7102
# 돋	-11.7102
# 듬	-11.7102
# 땀	-11.7102
# 랴	-11.7102
# 렛	-11.7102
# 밋	-11.7102
# 밍	-11.7102
# 삐	-11.7102
# 썩	-11.7102
# 앱	-11.7102
# 얕	-11.7102
# 엎	-11.7102
# 젤	-11.7102
# 짝	-11.7102
# 컵	-11.7102
# 콤	-11.7102
# 킷	-11.7102
# 틱	-11.7102
# 풋	-11.7102
# 핸	-11.7102
# 햇	-11.7102
# 홉	-11.7102
# 굽	-11.7102
# 팽	-11.7102
# 돔	-11.7102
# 탬	-11.7102
# 곶	-11.7102
# 뵈	-11.7102
# 뭇	-11.7102
# 않	-12.0944
# 잠	-12.1113
# 낮	-12.1115
# 뒤	-12.1121
# 룰	-12.2093
# 겔	-12.2102
# 깻	-12.2102
# 꼼	-12.2102
# 뀐	-12.2102
# 놔	-12.2102
# 닛	-12.2102
# 닭	-12.2102
# 뎃	-12.2102
# 랫	-12.2102
# 높	-13.1175
# 둠	-13.1851
# 돗	-13.1852
# 댓	-13.1853
# 닦	-13.1854
# 늬	-13.1855
# 뉜	-13.1856
# 놈	-13.1857
# 녔	-13.1858
# 넸	-13.1859
# 꽂	-13.186
# 꽁	-13.1861
# 궂	-13.1862
# 괜	-13.1863
# 핏	-13.1864
# 펩	-13.1865
# 팰	-13.1866
# 텅	-13.1867
# 챘	-13.1868
# 잿	-13.1869
# 옴	-13.187
# 옳	-13.1871
# 썬	-13.1872
# 싣	-13.1873
# 섣	-13.1874
# 섞	-13.1875
# 쁨	-13.1876
# 볍	-13.1877
# 밟	-13.1878
# 멤	-13.1879
# 맬	-13.188
# 띄	-13.1881
# 뜯	-13.1882
# 뚫	-13.1883
# 닿	-13.1884
# 눔	-13.1885
# 낯	-13.1886
# 껍	-13.1887
# 곰	-13.1888
# 픔	-13.1889
# 팝	-13.189
# 튼	-13.1891
# 튀	-13.1892
# 짧	-13.1893
# 앵	-13.1894
# 씻	-13.1895
# 싹	-13.1896
# 뭐	-13.1897
# 멋	-13.1898
# 뛴	-13.1899
# 늠	-13.19
# 눴	-13.1901
# 꺾	-13.1902
# 깎	-13.1903
# 긋	-13.1904
# 곁	-13.1905
# 컸	-13.1906
# 챗	-13.1907
# 잦	-13.1908
# 잣	-13.1909
# 씀	-13.191
# 샀	-13.1911
# 벙	-13.1912
# 벅	-13.1913
# 뤼	-13.1914
# 렷	-13.1915
# 랠	-13.1916
# 딱	-13.1917
# 낳	-13.1918
# 깝	-13.1919
# 훌	-13.192
# 팜	-13.1921
# 탱	-13.1922
# 춧	-13.1923
# 찔	-13.1924
# 짙	-13.1925
# 잊	-13.1926
# 씌	-13.1927
# 쏠	-13.1928
# 뻔	-13.1929
# 넴	-13.193
# 뀌	-13.1931
# 꼴	-13.1932
# 깃	-13.1933
# 갯	-13.1934
# 훔	-13.1935
# 횟	-13.1936
# 톰	-13.1937
# 찢	-13.1938
# 줌	-13.1939
# 쏘	-13.194
# 썼	-13.1941
# 멕	-13.1942
# 녁	-13.1943
# 핫	-13.1944
# 팎	-13.1945
# 즘	-13.1946
# 좁	-13.1947
# 잭	-13.1948
# 앗	-13.1949
# 쇠	-13.195
# 샌	-13.1951
# 뷔	-13.1952
# 밴	-13.1953
# 맑	-13.1954
# 껑	-13.1955
# 궤	-13.1956
# 휩	-13.1957
# 옆	-13.1958
# 쏴	-13.1959
# 쌓	-13.196
# 솟	-13.1961
# 뼈	-13.1962
# 밑	-13.1963
# 낌	-13.1964
# 깔	-13.1965
# 탠	-13.1966
# 쿼	-13.1967
# 췄	-13.1968
# 짚	-13.1969
# 옛	-13.197
# 쏟	-13.1971
# 뽑	-13.1972
# 덮	-13.1973
# 굳	-13.1974
# 헨	-13.1975
# 쫓	-13.1976
# 좀	-13.1977
# 멧	-13.1978
# 훼	-13.1979
# 켰	-13.198
# 읽	-13.1981
# 셋	-13.1982
# 빚	-13.1983
# 벗	-13.1984
# 믿	-13.1985
# 맺	-13.1986
# 룬	-13.1987
# 닷	-13.1988
# 뉘	-13.1989
# 갤	-13.199
# 헛	-13.1991
# 폼	-13.1992
# 펜	-13.1993
# 톱	-13.1994
# 뿌	-13.1995
# 붉	-13.1996
# 맛	-13.1997
# 랙	-13.1998
# 뚜	-13.1999
# 넥	-13.2
# 긍	-13.2001
# 봐	-13.2002
# 렐	-13.2003
# 튜	-13.2004
# 퀴	-13.2005
# 돕	-13.2006
# 곧	-13.2007
# 젊	-13.2008
# 빨	-13.2009
# 멈	-13.201
# 똑	-13.2011
# 쿄	-13.2012
# 죽	-13.2013
# 쇄	-13.2014
# 셈	-13.2015
# 삶	-13.2016
# 뒷	-13.2017
# 렴	-13.2018
# 덤	-13.2019
# 눠	-13.202
# 꼽	-13.2021
# 헬	-13.2022
# 딸	-13.2023
# 늦	-13.2024
# 콧	-13.2025
# 즉	-13.2026
# 잃	-13.2027
# 멀	-13.2028
# 듣	-13.2029
# 님	-13.203
# 캔	-13.2031
# 슷	-13.2032
# 끊	-13.2033
# 깊	-13.2034
# 밸	-13.2035
# 묻	-13.2036
# 팬	-13.2037
# 켓	-13.2038
# 흡	-13.2039
# 럭	-13.204
# 흉	-13.2041
# 컴	-13.2042
# 잇	-13.2043
# 얻	-13.2044
# 녹	-13.2045
# 얘	-13.2046
# 옮	-13.2047
# 냉	-13.2048
# 갔	-13.2049
# 겪	-13.205
# 웃	-13.2051
# 끌	-13.2052
# 뜻	-13.2053
# 꾸	-13.2054
# 쉽	-13.2055
# 떤	-13.2056
# 앨	-13.2057
# 빌	-13.2058
# 렇	-13.2059
# 캡	-13.206
# 덧	-13.2061
# 넷	-13.2062
# 섰	-13.2063
# 맡	-13.2064
# 촬	-13.2065
# 엑	-13.2066
# 젝	-13.2067
# 펼	-13.2068
# 잘	-13.2069
# 룹	-13.207
# 챙	-13.2071
# 홈	-13.2072
# 캠	-13.2073
# 좋	-13.2074
# 갖	-13.2075
# 끝	-13.2076
# 첫	-13.2077
# 텔	-13.2078
# 큰	-13.2079
# 륙	-13.208
# 탐	-13.2081
# 왼	-13.2082
# 쟁	-13.2083
# 숨	-13.2084
# 찾	-13.2085
# 혐	-13.2086
# 클	-13.2087
# 융	-13.2088
# 또	-13.2089
# 략	-13.209
# 롯	-13.2091
# 획	-13.2091
# 핵	-13.2092
# 앞	-13.2093
# 따	-13.2094
# 혔	-13.2095
# 듭	-13.2096
# 밝	-13.2096
# 확	-13.2097
# 곽	-13.2098
# 최	-13.2098
